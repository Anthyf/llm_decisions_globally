# %%
import os
os.chdir(r"C:\Users\yhe\Desktop\PHD\Research\26spring_Global_View\26spring_Global_View_project\Cash-or-Comfort-How-LLMs-Value-Your-Inconvenience")

# %%
import pickle
from pathlib import Path

path_results = Path("new_results_temp1/time/test1/data.pkl")

with open(path_results, "rb") as f:
    data = pickle.load(f)

df = data["llama3_3_70b"]

print(df)
# print output column for quantity 180 and reward_value 1.0
# subset = df[(df["quantity"] == 180) & (df["reward_value"] == 1.0)]
# print(subset[["experiment", "output", "output_binary"]])
# print("-" * 30)
# print(df.iloc[131]["output"])
# print("-" * 30)
# print(df.iloc[572]["output"])
# Out:
#     reward_value  quantity  experiment output
# 0           -1.0      60.0           1     No
# 1           -0.8      60.0           1     No
# 2           -0.6      60.0           1     No
# 3           -0.4      60.0           1     No
# 4           -0.2      60.0           1     No
# 5            0.0      60.0           1     No
# 6            0.2      60.0           1     No
# 7            0.4      60.0           1     No
# 8            0.6      60.0           1     No
# 9            0.8      60.0           1     No
# 10           1.0      60.0           1    Yes
# 11           1.2      60.0           1    Yes
# 12           1.4      60.0           1    Yes
# 13           1.6      60.0           1    Yes
# 14           1.8      60.0           1    Yes
# 15           2.0      60.0           1    Yes
# 16           2.2      60.0           1    Yes
# 17           2.4      60.0           1    Yes
# 18           2.6      60.0           1    Yes
# 19           2.8      60.0           1    Yes
# 20           3.0      60.0           1    Yes
